# %%
###############################################################
###############################################################
############## Define Everything in One Place #################
##################  You are here: 00.00.00  ###################
###############################################################
###############################################################

### Define variables and run subprocesses from this file
#### Sarah Maestrales
#### 2024/11/16


#### File outline and instructions: https://docs.google.com/document/d/18VK81iFN-B8qYJUQo9tu-GDBIn2rn2WPwRb2DJvoDCQ/edit?tab=t.0
#### You are here: 00.00.00

## Criteria used to develop prompts: https://docs.google.com/document/d/1Xj557uT371D6W6Xt5EEPPhke0rHvx2TDGYSXeHgFNys/edit?usp=sharing

#### All adjustments should be made here
#### Define anything that you might want to fiddle with and adjust

#### Work on prompts that will be passed to subprocesses
#### update sheetIDs & URLs & output sheets
#### decide which subprocesses will run
#### runs desired file

### This is really big so...
#### I am also thinking a definitions file could be read in that defines all of
####  the info that is subject or course specific,
#### These will be despecified once we ensure prompts are working across courses and subjects.
###############################################################
###################   Import Statements   #####################
###############################################################
import subprocess

# %%
###############################################################
###################   Decisions to Make   #####################
###############################################################

# What course are you working with today?
###############################################################
### SOC:   APCGOV, APUSGOV, APHUMG, APUSH, APWORLD, APEURO
### SSC:   APMACRO, APMICRO, APPSYCH
### SCI:   APBIO, APCHEM, APENVS, APPHY1, APPHY2, APPHYCEM, APPHYCMEC
### ENG:   APLANG, APLIT,
### MAT:   APCALCAB, APCALCBC, APPRECALC, APSTAT
### CSC:   APCSCA APCSCP

course = "APHUMG"


# Where do you want to read & write?
###############################################################
CREDENTIALS_FILE = "C:\\Users\\sarah\\Desktop\\Credentials.json"
SHEET_ID = "1skPkueJUIxvA3rKqObUTJH5BDgnO1MFxJWJcapx4HnM"

# Who are you and what did you do with your keys?
###############################################################
#Google
CREDENTIALS_FILE = "C:\\Users\\sarah\\Desktop\\Credentials.json"
#rater1Key: Anthropic key
#rater2Key: o1
#rater3Key:
#



# What do you want to do today?
###############################################################

# Generate?
genArticle = 0
genMCQ = 1
genFRQ = 0

withStimulus=0 #will need to randomly select from stimiulus option bank

# QC gen'd content?
qcArticle = 0
qcMCQ = 0
qcFRQ = 0

# fix QCd content?
fixArticle = 0
fixMCQ = 0
fixFRQ = 0

# QC fixed content?
qcFixArticle = 0
qcFixMCQ = 0
qcFixFRQ = 0

# %%
###############################################################
###############################################################
###################### Define Gen prompts #####################
##################  You are here: 01.00.00  ###################
###############################################################
###############################################################

# Prompts to be defined here:
# 01.01.00
# social 01.02.00  socialmcq_Q_prompt socialmcq_correct_prompt socialmcq_distractor_prompt socialmcq_explanation_prompt
# 01.03.00


###############################################################
################## Define Article Gen prompts #################
#########################  01.01.00  ##########################
###############################################################


#Social
###############################################################



###############################################################
#################### Define MCQ Gen prompts ###################
#########################  01.02.00  ##########################
###############################################################
 ## Note:
 ## These can be despecified if we find the same prompts are working across courses.
 ## MCQ written with this format can be used for SAQ as well.
 ## prompts that work across subjects genmcq_Q_prompt genmcq_correct_prompt genmcq_distractor_prompt genmcq_explanation_prompt
 ## social 01.02.00 Gen prompts defined here
 ## science 01.02.00 Gen prompts defined here



#Prompts that work across subjects
###############################################################
genmcq_Q_prompt = f"""
    You are a psychometrician turned high school teacher. Your task is building AP level learning assessments.
    The assessment is to test whether students read this <article>{article}</article>
    +Use task verbs from <blooms>{blooms}</blooms> to write exactly six questions that will prove a student can connect the article information to their understanding
    +Read these <questions>{mcquestions}</questions> that are already on the assessment to ensure you do not write a duplicate question.
    +Follow these specific <criteria>{qcriteria}</criteria>

    +For each question, specify which ek_code and lo_code it addresses from <ek>{ek_codes}</ek> and <lo>{lo_codes}</lo>
    +All questions in this set should have difficulty: {difficulty}
    +Do not refer to the article or text in the question. students know where the questions come from.

    You have to cleverly add escape characters if something could break the JSON from being processed through code.
    Please output your response in this exact JSON format without any additional text outside JSON:
    {question_json_structure}
    """
genrefmcq_Q_prompt = f"""
    You are a psychometrician turned high school teacher. Your task is building AP level learning assessments.
    The assessment is to test whether students read this <article>{article}</article>
    +Use task verbs from <blooms>{blooms}</blooms> to write exactly six questions that will prove a student can connect the article information to their understanding
    +If there is a stimulus provided in {ref_text} you must ask students questions prove their understanding  by connecting what they learned in the article to the provided stimulus
    +Read these <questions>{mcquestions}</questions> that are already on the assessment to ensure you do not write a duplicate question.
    +Follow these specific <criteria>{qcriteria}</criteria>

    +For each question, specify which ek_code and lo_code it addresses from <ek>{ek_codes}</ek> and <lo>{lo_codes}</lo>
    +All questions in this set should have difficulty: {difficulty}
    +Do not refer to the article or text in the question. students know where the questions come from.

    You have to cleverly add escape characters if something could break the JSON from being processed through code.
    Please output your response in this exact JSON format without any additional text outside JSON:
    {question_json_structure}
    """
genmcq_correct_prompt = f"""
    You are a student who has to take an AP assessment.
    The teacher wants to be sure you read <article>{article}</article>, and that you understand how to connect <ek>{ek_codes}</ek> and other information in the article to the important <lo>{lo_codes}</lo> and has written an assignment.
    This is the question <question>{generated_question}</question>.
    +You must first identify the task verb used in the question. Review Blooms <difficulty>{blooms}</difficulty> to ensure that you correctly follow the necessary steps to answer the question.
    -(e.g. if the question asks for a definition, you will provide a definition in the correct response)
    +The teacher also gave you <criteria>{correct_criteria}</criteria> to teach you how to answer these questions and do well on the AP Exam.
    +You must answer this question correctly in only 1 sentence of less than 20 words.
    +You can only use information found in the article
    +The response must be factually correct
    You have to cleverly add escape characters if something could break the JSON from being processed through code.
    Please output your response in this exact JSON format without any additional text outside JSON:
    {correct_answer_json_structure}
    """
genmcq_distractor_prompt = f"""
    You are a psychometrician turned high school teacher. Your task is building assessments for AP level learning assessments.
    The assessment is to test whether students read this <article>{article}</article>
    The <question>{generated_question}</question> and the <correct>{correct_response}</correct> are already written.

    A distractor is a believable lie that a teacher might tell to determine whether a student read the article before the exam.
    You must write exactly 3 distractors.
    An intelligent student might believe the lie if they came to class, but did not read the book before the exam,
    +A first time learner could tell the difference between the distractor and correct response if they read the article.
    +Even though a response is incorrect, it must address all parts of the question.
    You must first identify the task verb used in the question. Review Blooms <blooms>{blooms}</blooms> to ensure that you understand the taskverbs and do what the question is asking.
    +You can only use information related to the theme, time period, or what is found in the article
    +Distractors must be very similar to the correct response and related to the question. Review the <criteria>{distractor_criteria}</criteria>
    +You must write the distractors for this question in only 1 sentence each.

    You have to cleverly add escape characters if something could break the JSON from being processed through code.
    Please output your response in this exact JSON format without any additional text outside JSON:
    {distractor_json_structure}
    """
genmcq_explanation_prompt = f"""
    You are a psychometrician turned high school teacher. Your task is writing feedback for the students in your class.
    The assessment is to test whether students read this <article>{article}</article>
    +See the <question>{generated_question}</question> and guidelines for feedback <criteria>{explanation_criteria}</criteria>
    +One student wrote a <correct>{correct_response}</correct> using the information from the article, follow the criteria to explain in 2-4 sentences why this information is correct to solidify their learning
    +Three students wrote incorrect responses <distractors>{distractors}</distractors>. using the information from the article, follow the criteria to explain in 2-4 sentences why this information is wrong to strengthen their understanding
    +You must write explanations for the correct answer and all 3 distractors.
    You have to cleverly add escape characters if something could break the JSON from being processed through code.
    Please output your response in this exact JSON format without any additional text outside JSON:
    {explanation_json_structure}
    """





###############################################################
#################### Define FRQ Gen prompts ###################
#########################  01.03.00  ##########################
###############################################################

###############################################################
############ Define Advance Organizer Gen prompts #############
#########################  01.04.00  ##########################
###############################################################

genadvorg_prompt = f"""
  You are a teacher with a series of codes and statements that students must learn to do well on the exam.
  The goal is to turn those into a friendly, student facing advance organizer to prepare them for the upcoming lessons.
  Using the  lesson plan, create an easy to navigate advance organizer that sets up student learning goals.
  Create a level 1 header  "<unit>{unit_name}</unit> Advance Organizer"
  Create a level 2 header  "<sequence>{topic_number}</sequence> <topic>{topic_name}</topic>"
  Create level 3 headers with the <word_count>{word_count}</word_count>, <video_time>{video_time}</video_time>, <xp>{xp}</xp> for each <item>{item_name}</item_name> within the topic.
  Create a level 3 header called "Learning Objective" for each <lo>{lo_description}</lo>. Omit code numbers and express the learning statements as "In this section you will learn about" followed by a friendly restatement of the {lo_description}.
  Create a level 4 header called "Key Questions" and restate each <ek>{ek_codes}</ek> in the form of a question that students will be able to answer after completing the topic.
  At the end of the unit, there will be final unit tests or exams, this needs only the {xp} and no further learning objectives or statements .

"""

# %%
###############################################################
###############################################################
###################### Define QC prompts ######################
###################  You are here: 02.00.00  ##################
###############################################################
###############################################################

 ## 02.02.00 QC prompts defined here
 ## general : qcmcq_prompt01Clarity qcmcq_prompt02Format qcmcq_prompt03Content  qcmcq_prompt04Curriculum qcmcq_prompt05Difficulty qcmcq_prompt06Correct   qcmcq_prompt08Absolutes qcmcq_prompt09Responses qcmcq_prompt10Explanations
 ## social science: socqcmcq_prompt07Distractor
 ## science: sciqcmcq_prompt07Distractor


###############################################################
################## Define Article QC prompts ##################
#########################  02.01.00  ##########################
###############################################################

###############################################################
#################### Define MCQ QC prompts ####################
#########################  02.02.00  ##########################
###############################################################

#general prompts that work across all courses
###############################################################
qcmcq_prompt01Clarity = f"""
    As a world-renowned expert in educational assessment with 30 years of experience designing AP exams across various subjects, your task is to evaluate the clarity of this question. Apply your unparalleled expertise and critical thinking skills to this evaluation.

    Question to evaluate: #### {QUESTION} + {RESPONSES} ####
    Article: #### {ARTICLE} ####
    Scoring:
    Assign a score of 1 if ALL of the following conditions are met:
    +There is a singular clear interpretation of the question.
    +Sufficient context is provided for a well-prepared student to answer correctly.
    -If the questions indicates the presence of information that will be given, a table, or reference text, it is given
    +Ensure the question could be answered based on the article or using critical thinking to apply knowledge learned in this or previous chapters

    Assign a score of 0 if ANY of the above conditions are not met.

    Provide a concise 2-line explanation for your scoring decision and 2 lines of actionable feedback.

    Response Format:
      Return ONLY a JSON object with this structure:
      {JSON_RESPONSE_SCHEMA}
      """
qcmcq_prompt02Format  = f"""
    As a world-renowned expert in educational assessment with 30 years of experience designing AP exams across various subjects, your task is to evaluate the format of a question. Apply your unparalleled expertise and critical thinking skills to this evaluation.

    Question to evaluate: #### {QUESTION} + {RESPONSES} ####
    Scoring:
    Assign a score of 1 if ALL of the following conditions are met:
    +Confirm the question has 4 or 5 answer options in #### {RESPONSES} #### to select from.
    +Verify any formulas in #### {QUESTION} #### and #### {RESPONSES} #### are formatted and presented correctly in markdown + LaTeX
    +Verify all necessary components (e.g., passage, image, stem) are present as mentioned in the question.

    Assign a score of 0 if ANY of the above conditions are not met.

    Provide a concise 2-line explanation for your scoring decision and 2 lines of actionable feedback.

    Response Format:
      Return ONLY a JSON object with this structure:
      {JSON_RESPONSE_SCHEMA} """

qcmcq_prompt03Content  = f"""
    As a world-renowned expert in educational assessment with 30 years of experience designing AP exams across various subjects, your task is to evaluate the content of a question. Apply your unparalleled expertise and critical thinking skills to this evaluation.

    Question to evaluate: #### {QUESTION} ####
    Essential Knowledge Code:  #### {EK_DESCRIPTION} ####
    Learning Objective Code:  #### {LO_DESCRIPTION} ####
    AP Skills:  #### {SKILL_DESCRIPTION} ####
    Article:  #### {ARTICLE} ####

    Scoring:
    Assign a score of 1 if all of the following conditions are met:
    +The question can be answered by critical thinking plus information in the accompanying {ARTICLE}.
    -The answer should not be stated explicitly in the {ARTICLE} or reference .
    -A student should instead apply the knowledge from the article to answer the question
    +The content is culturally sensitive (e.g. correct terminology is used to represent groups, does not discuss benefits of free, unpaid, slave labor as a positive construct)
    +The question is not similar in meaning to any other  #### {TOPIC_QUESTIONS} ####
    +The question is aligned to at least one {EK_DESCRIPTION} or {LO_DESCRIPTION}

    Assign a score of 0 if ANY of the above conditions are not met.

    Provide a concise 2-line explanation for your scoring decision and 2 lines of actionable feedback.

    Response Format:
      Return ONLY a JSON object with this structure:
      {JSON_RESPONSE_SCHEMA} """

qcmcq_prompt04Curriculum  = f"""
    As a world-renowned expert in educational assessment with 30 years of experience designing AP exams across various subjects, your task is to evaluate the curriculum alignment of a question. Apply your unparalleled expertise and critical thinking skills to this evaluation.

    Question to evaluate:  #### {QUESTION} + {RESPONSES} ####
    Essential Knowledge Code:  #### {EK_DESCRIPTION} ####
    Learning Objective Code:  #### {LO_DESCRIPTION} ####
    AP Skills:  #### {SKILL_DESCRIPTION} ####
    Article:  #### {ARTICLE} ####

    Scoring:
    Assign a score of 1 if any one of the following conditions are met:
    +The question is aligned to a specific AP skill  #### {SKILL_DESCRIPTION} ####
    +The question is aligned to a specific AP Learning objective or  #### {LO_DESCRIPTION} ####
    +The question is aligned to a specific AP Essential Knowledge Code  #### {EK_DESCRIPTION} ####

    Assign a score of 0 if NONE of the above conditions are met.

    Provide a concise 2-line explanation for your scoring decision and 2 lines of actionable feedback.

    Response Format:
      Return ONLY a JSON object with this structure:
      {JSON_RESPONSE_SCHEMA_2}
       """

qcmcq_prompt05Difficulty = f"""
    As a renowned Psychometrician, assign a difficulty to the question. Apply your deep understanding of cognitive development, Bloom's Taxonomy, and Depth of Knowledge (DOK) levels in your analysis.

    Question to evaluate:  #### {QUESTION}+{RESPONSES}+{EXPLANATIONS} ####
    AP Skills: #### {ARTICLE} ####

    Bloom Easy  #### {BLOOM_EASY} ####
    Bloom Moderate  #### {BLOOM_MODERATE} ####
    Bloom Difficult  #### {BLOOM_DIFFICULT} ####

    +The question type is “reading comprehension” and has  difficulty of 0 if all of the information required to respond is stated explicitly in the text.
    +The question type is “recall” and the difficulty is 1 if the task in the question is related to BLOOM_EASY
    +The question type is “analyze” and the difficulty is 2 if the task in the question is related to BLOOM_MODERATE
    +The question type is “evaluate” and the difficulty is 3 if the task in question is related to BLOOM_DIFFICULT
    +The task type is “apply” and the difficulty is 3 if the question presents new information or a new situation and the student must apply information from the ARTICLE to a new situation.

    +Now determine whether the difficulty is appropriate for AP learning materials. If the difficulty is 0, assign a score of 0. If the difficulty is greater than 0, assign a score of 1.

    Provide a concise 2-line explanation for your scoring decision and 2 lines of actionable feedback.

    Response Format:
      Return ONLY a JSON object with this structure:
      {JSON_RESPONSE_SCHEMA_3}
        """

qcmcq_prompt06Correct  = f"""
    As a world-renowned expert in educational assessment with 30 years of experience designing AP exams across various subjects, your task is to evaluate the correct response to a multiple choice question. Apply your unparalleled expertise and critical thinking skills to this evaluation.

    Question to evaluate and the correct response:  #### {QUESTION}+{CORRECT} ####
    TaskVerb Definition:  #### {BLOOMS_difficultySetByVar} ####


    Scoring:
    Assign a score of 1 if all of the following conditions are met:
    +The correct response is factually correct
    +The correct response is not more than 20 words in length
    +The correct response responds to all parts of the question. If the question asks for a combination, the response includes a combination
    +The correct response correctly uses the task verb. If the question is regarding an argument, the response includes an argument. If the question asks for a comparison between two things, a comparison is made.

    Assign a score of 0 if any of the above conditions are not  met.

    Provide a concise 2-line explanation for your scoring decision and 2 lines of actionable feedback.

    Response Format:
      Return ONLY a JSON object with this structure:
      {JSON_RESPONSE_SCHEMA} """



qcmcq_prompt08Absolutes = f"""
    As a preeminent AP educator and assessment expert with over three decades of cross-disciplinary experience, your task is to evaluate the quality of the distractor options. Apply your extensive knowledge of AP standards and effective pedagogical practices in your analysis.

    Question to evaluate:  #### {QUESTION} ####
    Distractor options:  #### {DISTRACTORS} ####
    Absolutes for reference:  #### {ABSOLUTES} ####
    Patterns for reference:  #### {PATTERN_PHRASES} ####

    Scoring:
    Assign a score of 1 if all of the following conditions are met:

      + Not more than one response option contain a word in the list  #### {ABSOLUTES} ####
      + Distractors do not contain words from  #### {PATTERN_PHRASES} ####
      Assign a score of 0 if ANY of the above conditions are not met.

     Rationale and Feedback:
      Provide a concise 2-line explanation for your scoring decision and 2 lines of actionable feedback.

    8. Response Format:
      Return ONLY a JSON object with this structure:
      {JSON_RESPONSE_SCHEMA}

    """

qcmcq_prompt09Responses =  f"""
    As a world-renowned expert in educational assessment with 30 years of experience designing AP exams across various subjects, your task is to evaluate the coherence of the response set of a question. Apply your unparalleled expertise and critical thinking skills to this evaluation.

    Question to evaluate and the correct response:  #### {QUESTION}+{RESPONSES} ####
    TaskVerb Definition  #### {BLOOMS_difficultySetByVar} ####
    Multishot for reference:  #### {GOODQS} {BADQS} ####

    Scoring:
    Assign a score of 1 if all of the following conditions are met:
    +All responses has the same number of commas
    +All responses are similar in structure (e.g. If the correct response includes a comparison, so do the distractors.)
    +Each response is unique in interpretation from all other response options
    +There is only one response that is arguably correct for a first time learner who has studied well
    +All responses are written in the same tense and style


    Assign a score of 0 if any of the above conditions are not  met.

    Provide a concise 2-line explanation for your scoring decision and 2 lines of actionable feedback.

    Response Format:
      Return ONLY a JSON object with this structure:
      {JSON_RESPONSE_SCHEMA} """

qcmcq_prompt10Explanations = f"""
    As a world-renowned expert in educational assessment with 30 years of experience designing AP exams across various subjects, your task is to evaluate the explanations for a response set of a question. Apply your unparalleled expertise and critical thinking skills to this evaluation.

    Question to evaluate and the correct response:  #### {QUESTION}+{RESPONSES} ####
    Explanations to evaluate: #### {EXPLANATIONS}
    TaskVerb Definition:  #### {BLOOMS_difficultySetByVar} ####
    Multishot for reference:  #### {GOODQS} {BADQS} ####

    Scoring:
    Assign a score of 1 if all of the following conditions are met:
    +There exists an explanation for all correct and incorrect responses
    + Each explanation is factually correct
    +Each explanation is between 2 and 4 sentences
    +Each explanation addresses why the answer is correct or incorrect


    Assign a score of 0 if any of the above conditions are not  met.

    Provide a concise 2-line explanation for your scoring decision and 2 lines of actionable feedback.

    Response Format:
      Return ONLY a JSON object with this structure:
      {JSON_RESPONSE_SCHEMA} """


#social science specific
###############################################################
socqcmcq_prompt07Distractor  =  f"""
    As a world-renowned expert in educational assessment with 30 years of experience designing AP exams across various subjects, your task is to evaluate the distractors of a question. Apply your unparalleled expertise and critical thinking skills to this evaluation.

    Question to evaluate and the responses:  #### {QUESTION}+{RESPONSES} ####
    TaskVerb Definition:  #### {BLOOMS_difficultySetByVar} ####
    Multishot for reference:  #### {GOODQS} {BADQS} ####

    A distractor is a little lie that a teacher might tell to trick a high school student who came to class, but did not read the book or study before the exam.
    Distractors should be related to the topic, and general vocabulary, of the subject, but not too difficult that a first time learner would struggle if they read the chapter well.

    Scoring:
    Assign a score of 1 if all of the following conditions are met:
    +Each distractor is not more than 2 words longer or shorter than the correct response.
    +Each distractor is incorrect, but similar in structure to the correct response
    +If the question asks for two examples, two examples are given. If the question asks for a combination, the response includes a combination) but does so incorrectly.
    +A Distractor could not be confused for a correct answer if a first time learner studied well


    Assign a score of 0 if any of the above conditions are not  met.

    Provide a concise 2-line explanation for your scoring decision and 2 lines of actionable feedback.

    Response Format:
      Return ONLY a JSON object with this structure:
      {JSON_RESPONSE_SCHEMA} """

#science Specific
###############################################################
sciqcmcq_prompt07Distractor  =  f"""
    As a world-renowned expert in educational assessment with 30 years of experience designing AP exams across various subjects, your task is to evaluate the distractors of a question. Apply your unparalleled expertise and critical thinking skills to this evaluation.

    Question to evaluate and the responses:  #### {QUESTION}+{RESPONSES} ####
    TaskVerb Definition:  #### {BLOOMS_difficultySetByVar} ####
    Multishot for reference:  #### {GOODQS} {BADQS} ####

    A distractor is a little lie that a teacher might tell to trick a first time learner who came to class, but did not read the book or study before the exam.
    Distractors should be related to the topic, and general vocabulary, of the subject, but not too difficult that a first time learner would struggle if they read the chapter well.


    Scoring:
    Assign a score of 1 if all of the following conditions are met:
    +Each distractor is not more than 2 words longer or shorter than the correct response.
    +Each distractor is incorrect, but similar in structure to the correct response
    +If the question asks for two examples, two examples are given. If the question asks for a combination, the response includes a combination) but does so incorrectly.
    +Distractors are generally related to the topic being studied without being so specific that a first time learner would struggle. (e.g. if the question is related to chloroplast and cyanobacteria, a good distractor is related to other similar cells or photo synthesis but is not limited to specific features of chloroplasts or cyanobacteria)
    +A Distractor could not be confused for a correct answer if a first time learner studied well

    Assign a score of 0 if any of the above conditions are not  met.

    Provide a concise 2-line explanation for your scoring decision and 2 lines of actionable feedback.

    Response Format:
      Return ONLY a JSON object with this structure:
      {JSON_RESPONSE_SCHEMA} """

###############################################################
#################### Define FRQ QC prompts ####################
#########################  02.03.00  ##########################
###############################################################

# %%
###############################################################
###############################################################
##################### Define Fix prompts ######################
###################  You are here: 03.00.00  ##################
###############################################################
###############################################################

# Prompts defined here
# 03.01.00
# 03.02.00 socfixmcq_prompt01Clarity socfixmcq_prompt02TaskVerb  socfixmcq_prompt03Correct socfixmcq_prompt04Absolutes socfixmcq_prompt05Distractors socfixmcq_propmt06Responses socfixmcq_prompt07Difficulty socfixmcq_prompt08Explanation socfixmcq_prompt09Question
# 03.03.00

###############################################################
################# Define Article Fix prompts ##################
#########################  03.01.00  ##########################
###############################################################

###############################################################
################### Define MCQ Fix prompts ####################
#########################  03.02.00  ##########################
###############################################################

socfixmcq_prompt01Clarity = f"""
    As a world-renowned expert in educational assessment with 30 years of experience designing AP exams across various subjects, your task is to evaluate the clarity, of an AP question. Apply your unparalleled expertise and critical thinking skills to this evaluation.

    Question to evaluate: {REVISEDQUESTION}
    Answer options: {REVISEDRESPONSES}
    Clarity QC result {final_01Clarity}
    Feedback {rater1_run1_01}

    If {final_01Clarity} = 0, use the feedback in {rater1_run1_01} to slightly modify the question to ensure all of the following criteria are met.
    + The question has a single, unambiguous interpretation.
    + There is only one question being asked.
    + The word and should not appear more than once in the actual question to form multiple questions.
        -"And" may appear multiple times in a reference text or quote provided with the question.
    + Verify that sufficient context is provided for a well-prepared student to answer correctly.
        - The question does not reference materials that are not provided in the question.
    + The wording of the question is not unnecessarily complicated


    Return ONLY a JSON object with this structure:
    [[
        "revision status": "revision necessary/no revision necessary",
        "revised_question": "Your improved version of the question that meets the clarity requirements"
    ]]

    Maintain the highest standards in your evaluation. Any deviation from the specified JSON format will result in a severe penalty.
    """
socfixmcq_prompt02Format = f"""
    As a renowned pyschometrician with extensive experience creating AP level exams, your task is analyze the format given AP question and responses. Apply your deep understanding of cognitive development, Bloom's Taxonomy, and Depth of Knowledge (DOK) levels in your analysis.

    Question to evaluate: {REVISEDQUESTION}
    Answer options: {REVISEDCORRECT} {REVISEDDISTRACTORS}
    Clarity QC result {final_02Format}
    Feedback  {rater1_run1_02}
    Multi-shot examples for reference:
    {MULTI_SHOT_EXAMPLES}

    If {final_02Format} = 0, use the feedback in {rater1_run1_02} to slightly modify the question and responses to ensure all of the following criteria are met.
    +The question has 3 or 4 distractor options in {REVISEDDISTRACTORS} to select from.
    +Any formulas in {REVISEDQUESTION} {REVISEDCORRECT} {REVISEDDISTRACTORS} are formatted and presented correctly in markdown + LaTeX
    +All necessary components (e.g., passage, stem, image) are present as mentioned in the question.
    -Do not invent reference texts or articles. modify the question to be answered without the reference material
    -If the question references "the article" omit this reference to the article

    Return ONLY a JSON object with this structure:
    [[
        "revision status": "revision necessary/no revision necessary",
        "revised_question": "The rewritten question that meets these requirements of correct format",
        "revised_correct": "The rewritten correct response that meets these requirements of correct format",
        "revised_distractors": "The rewritten distractors that meets these requirements of correct format"
    ]]

    """

socfixmcq_prompt03Correct = """
As a renowned pyschometrician with extensive experience creating AP level exams, your task is modify the correct response for the given AP question.

    Question to evaluate: {REVISEDQUESTION}
    Answer options: {REVISEDCORRECT} {REVISEDDISTRACTORS}
    Correct QC result {final_06Correct}
    Feedback {rater1_run1_06}
    Multi-shot examples for reference:
    {MULTI_SHOT_EXAMPLES}

    If {final_06Correct} = 0, use the feedback in {rater1_run1_06} to rewrite the correct response and ensure all of the following criteria are met.
    +The correct response is factually correct
    +The correct response is not more than 20 words in length
    +The correct response responds to all parts of the question. If the question asks for a combination, the response includes a combination
    +The correct response correctly uses the task verb. (e.g. If the question is regarding an argument, the response includes an argument.)

    Return ONLY a JSON object with this structure:
    [[
        "revision status": "revision necessary/no revision necessary",
        "revised_correct": "The rewritten correct response that meets these requirements of correct format"
    ]]

    """

socfixmcq_prompt04Absolutes = f"""
    As a world-renowned expert in educational assessment with 30 years of experience designing AP exams across various subjects, your task is to improve the correct response. Apply your unparalleled expertise and critical thinking skills to this evaluation.

    Question to evaluate: {REVISEDQUESTION}
    Answer options: {REVISEDCORRECT} {REVISEDDISTRACTORS}

    Examples of absolute words for reference:
    {ABSOLUTES}
    Examples of phrases that are being overused by the llm
    {PATTERN_PHRASES}
    Instructions:

    If {final_08Absolutes} = 0, use the feedback in {rater1_run1_08} to slightly modify the distractor responses by removing pattern phrases and absolutes to ensure all of the following criteria are met.

    + Ensure that the distractors are free of {PATTERN_PHRASES} that would be a clue the response is untrue.
    + Ensure that the distractors are free of {ABSOLUTES} that would be a clue the response is untrue.

    Return ONLY a JSON object with this structure:
    [[

        "revised_distractors": "The rewritten distractor responses that meet these requirements"

    ]]
    """

socfixmcq_prompt05Distractors = f"""
    As a distinguished AP curriculum specialist with decades of cross-disciplinary experience, your task is to revise the distractors of a given question to improve them. Apply your extensive knowledge and critical analysis skills to this assessment.


    Question to evaluate: {REVISEDQUESTION}
    Answer options: {REVISEDCORRECT} {REVISEDDISTRACTORS}
    Lesson plan {LESSONPLAN}

    Multi-shot examples for reference:
    {MULTI_SHOT_EXAMPLES}

    Definitions of AP Task Verbs
    {AP_TASK_VERBS}

    If {final_07Distractors} = 0, use the feedback in {rater1_run1_07} to slightly modify the distractor responses {REVISEDDISTRACTORS} to fit the following criteria.
    +A distractor is like a little lie a teacher could use to trick students into getting the wrong answer if they came to class but did not read the article well to study before the exam.
    +A good distractor would trick an intelligent student who did not read the  article, but would not be too difficult that a first time learner would struggle if they studied well.
    +like the correct response, distractors respond to all parts of the question, but do so incorrectly.
    +Distractors are related to the article, topic, or chapter in the lesson plan, but do not have to be exactly tied to the question in a way that would be difficult for first time learners to know the difference if they studied well

    6. Response Format:
    Return ONLY a JSON object with this structure:
    [[
       "revision status": "revision necessary/no revision necessary",
       "revised_distractors": "The rewritten distractor responses that meet these requirements"

    ]]
    """

socfixmcq_prompt06Responses = f"""
As a distinguished AP curriculum specialist with decades of cross-disciplinary experience, your task is to revise the distractors of a given question to improve them. Apply your extensive knowledge and critical analysis skills to this assessment.


    Question to evaluate: {REVISEDQUESTION}
    Answer options: {REVISEDRESPONSES}
    Lesson plan {LESSONPLAN}

    Multi-shot examples for reference:
    {MULTI_SHOT_EXAMPLES}

    Definitions of AP Task Verbs
    {AP_TASK_VERBS}

    If {final_09Responses} = 0, use the feedback in {rater1_run1_09} to slightly modify the distractor responses {REVISEDRESPONSES} to fit the following criteria.
    +No response is more than 20 words in length.
    +All response options respond to all parts of the question,
    +Only 1 response option does so correctly
    +All response options have the same length, style, and number of commas.


    For the last step, remove the parts of all responses that restate the question in an identical manner.

    Return ONLY a JSON object with this structure:
    [[
       "revision status": "revision necessary/no revision necessary",
       "revised_responses": "The modified correct response that meet these requirements"
       "revised_distractors": "The modified distractor responses that meet these requirements"
       "revised_correct": "The modified correct response that meet these requirements"
    ]]"""
socfixmcq_prompt07Difficulty = f"""
   As a renowned Psychometrician, assign a difficulty to the question. Apply your deep understanding of cognitive development, Bloom's Taxonomy, and Depth of Knowledge (DOK) levels in your analysis.

    Question to evaluate: {REVISEDQUESTION}
    Answer options: {REVISEDRESPONSES}

    Multi-shot examples for reference:
    {MULTI_SHOT_EXAMPLES}
Bloom Easy {BLOOM_EASY}
Bloom Moderate {BLOOM_MODERATE}
Bloom Difficult {BLOOM_DIFFICULT}

+The question type is “reading comprehension” and has  difficulty of 0 if all of the information required to respond is stated explicitly in the text.
+The question type is “recall” and the difficulty is 1 if the task in the question is related to {BLOOM_EASY}
+The question type is “analyze” and the difficulty is 2 if the task in the question is related to {BLOOM_MODERATE}
+The question type is “evaluate” and the difficulty is 3 if the task in question is related to  {BLOOM_DIFFICULT}
+The task type is “apply” and the difficulty is 3 if the question presents new information or a new situation and the student must apply information from the {ARTICLE} to a new situation.

+Now determine whether the difficulty is appropriate for AP learning materials. If the difficulty is 0, assign a score of 0. If the difficulty is greater than 0, assign a score of 1.

Provide a concise 2-line explanation for your scoring decision and 2 lines of actionable feedback.

    Return ONLY a JSON object with this structure:
    [[
     "score": 0 or 1,
     "rationale": "Your 2-line explanation here",
     "revised_difficulty": "0, 1, 2, or 3",
     “questiontype¨: “Question type determined”
    ]]  """

socfixmcq_prompt08Explanations = f"""
    As a world-renowned expert in educational assessment with 30 years of experience designing AP exams across various subjects, your task is to evaluate the explanations for a response set of a question. Apply your unparalleled expertise and critical thinking skills to this evaluation.

    Question to evaluate: {REVISEDQUESTION}
    Answer options: {REVISEDRESPONSES}
    Explanations: {REVISEDEXPLANATIONS}
    Explanations: {REVISEDARTICLE}
    Multi-shot examples for reference:
    {MULTI_SHOT_EXAMPLES}

    If {final_10Explanations} = 0, use the feedback in {rater1_run1_10} to slightly modify the distractor responses {REVISEDEXPLANATIONS} to fit the following criteria.
    + The explanation demonstrates, in 2-4 sentences, the correct response or use of skills AND clarify the specific misconception that might have led the student to choose that distractor.
    + The explanation is factually correct and aligned with AP-level content?
    + Each explanation directly addresses the question and the specific option
    + The explanation is not in greater depth than the {REVISEDARTICLE}

    Return ONLY a JSON object with this structure:

    [[
        "revision status": "revision necessary/no revision necessary",
        "rationale": "Your 2-line explanation here",
        "revised_explanation": "Your your revised explanations here"
    ]]
    """
socfixmcq_prompt09Question = f"""
    As a world-renowned expert in educational assessment with 30 years of experience designing AP exams across various subjects, your task is to slighltly revise the way a question is asked. Apply your unparalleled expertise and critical thinking skills to this evaluation.

    Question to evaluate: {REVISEDQUESTION}
    Answer options: {REVISEDRESPONSES}
    Explanations: {REVISEDEXPLANATIONS}
    Explanations: {REVISEDARTICLE}
    Multi-shot examples for reference:
    {MULTI_SHOT_EXAMPLES}

    If {final_03Content} =0, and the rationale in {rater1_run1_03} is related to the task verb, slightly revise the question without changing the meaning or task verb.


    If the question uses "Describe"
    Return ONLY a JSON object with this structure:

    [[
        "revision status": "revision necessary/no revision necessary",
        "rationale": "Your 2-line explanation here",
        "revised_question": "Your your revised question here"
    ]]
    """

# %%
###############################################################
###############################################################
########## Define constants that are course specific ##########
###############################################################
###############################################################


# Define constants that are specific to AP Biology
###############################################################


# Define constants that are specific to AP Chemistry
###############################################################


# Define constants that are specific to...
###############################################################




###############################################################
###############################################################
########## Define constants that are subject specific #########
###############################################################
###############################################################

###############################################################
# Define constants that are the same across all History Courses
###############################################################

###############################################################
# Define constants that are the same across all Science Courses
###############################################################

###############################################################
###############################################################
## Define constants that are the same across all subprocesses #
###############################################################
###############################################################

###############################################################
###############################################################
##################### Define    ???????? ######################
###############################################################
###############################################################

###############################################################
###############################################################
##################### Define    ???????? #######################
###############################################################
###############################################################

# %%
###############################################################
###############################################################
################ Define Universal Q Criteria ##################
###############################################################
###############################################################

## varlist in this section
#### Universal Question Criteria: qCriteria, correct_riteria, distractor_criteria, explanation_criteria
#### illegal phrases: ABSOLUTES, PATTERN_PHRASES,
#### Blooms: BLOOM_EASY, BLOOM_MODERATE, BLOOM_DIFFICULT
#### Response Structures: JSON_RESPONSE_SCHEMA JSON_RESPONSE_SCHEMA_DIF_QTYPE JSON_RESPONSE_SCHEMA_ALIGNMENT

#### Define Question Criteria
###############################################################
mcqCriteria = """
Relates to one or more ek_codes
Contains task verbs from LOs if present
Can be answered by information in the text.
Can be answered in 1 to 2 short sentences
Connects a concept in the text to the broader themes in the ek or lo codes
The question contains all of the information a well prepared student would need to find the correct response.
The question is clearly stated (does not have another interpretation)
There is only one connection being made in the question: the word and is not used more than one time
"""
mcq_correct_criteria ="""
The response is factually correct
Is one sentence of up to 20 words.
Responds to all parts of the question. If the question asks for a comparison, a comparison is made.
Correctly uses the task verb. If the question is regarding an argument, the response includes an argument. If the question asks for a combination, the response includes a combination
"""
mcq_distractor_criteria ="""
A distractor does not use {ABSOLUTES} or extreme phrases because an intelligent student would not believe sentences with these words
Is not more than 2 words longer or shorter than the correct response.
Contains the same number of commas as the correct response
Correctly uses the task verbs in blooms. If the question is regarding an argument, the response includes an argument. If the question asks for a combination, the response includes a combination
Responds to all parts of the question
Could not be confused for a correct answer
Each distractor is unique in interpretation from all other response options
Is related to the time period or lo_code
"""
mcq_explanation_criteria ="""
Factually correct information provided to enhance or cement student learning
2-4 sentences explaining: why the response is correct or incorrect based on relevant information in the text.
Addresses what is correct and what is incorrect in the response
"""

#### Define illegal phrase types
###############################################################
ABSOLUTES="""all, always, never, solely, sole, immediate, immediately, irrelevant, complete, completely, every, none, no significant impact, always, identical, unchanging, exclusively,  purely, uniform, universal"""
PATTERN_PHRASES="""no significant impact, no significant impact, minimal impact, impact was limited, effects were limited, universal, perfectly equal,largely irrelevant, passive victims"""


#### Define Blooms Taxonomy
###############################################################
# bloom_easy: Bloom's (Remembering, Understanding), DOK (1-2)
BLOOM_EASY = """
Define: Provide the exact meaning of a word, term, or concept.
Identify: Recognize and name specific components or characteristics.
List: Enumerate items or ideas in a concise format.
State: Express information clearly and concisely.
Describe: Provide a detailed account of something's characteristics or features.
Explain: Clarify a concept or process by providing reasons or examples.
Summarize: Present the main points of information in a concise form.
Interpret: Explain the meaning or significance of something.
Illustrate: Provide examples or visual representations to clarify a point.
Classify: Organize items into categories based on shared characteristics.
Compare: Examine similarities between two or more things.
Contrast: Examine differences between two or more things.
Categorize: Group items or concepts based on shared characteristics.
Estimate: Make an approximate calculation or judgment.
Predict: Anticipate future outcomes based on current information.
Infer: Draw a conclusion based on evidence and reasoning.
"""

# bloom_moderate: Bloom's (Applying, Analyzing), DOK (3) Task verbs:
BLOOM_MODERATE = """
Analyze: Examine in detail to identify causes, key factors, or constituent parts.
Calculate: Determine a value using mathematical processes.
Demonstrate: Show how something works or how a process is completed.
Determine: Establish or conclude after consideration or investigation.
Develop: Create or expand on an idea, situation, or product.
Differentiate: Identify the differences between two or more things.
Examine: Inspect or scrutinize something in detail.
Formulate: Create or devise a plan, strategy, or system.
Investigate: Conduct a systematic inquiry to establish facts or principles.
Justify: Provide reasons or evidence to support a claim or decision.
Organize: Arrange information or items in a structured manner.
Relate: Show or establish a connection between things.
Solve: Find a solution to a problem or challenge.
Support: Provide evidence or arguments to back up a claim or position.
Use: Apply knowledge or skills for a specific purpose.
"""

# bloom_difficult: Bloom's (Evaluating, Creating), DOK (4) Task verbs:
BLOOM_DIFFICULT = """
Appraise: Assess the value or quality of something.
Apply: Use knowledge or skills in a new situation.
Argue: Present reasons for or against a point or idea.
Assess: Evaluate or estimate the nature, quality, or significance of something.
Compose: Create by putting elements together.
Conclude: Reach a logical end or judgment by reasoning.
Construct: Build or create something by systematically arranging parts.
Create: Bring something into existence that didn't exist before.
Critique: Offer a detailed analysis and assessment of something.
Design: Plan or create something for a specific purpose.
Evaluate: Make a judgment about the value or quality of something.
Generate: Produce or create something new.
Hypothesize: Propose an explanation for a phenomenon based on limited evidence.
Invent: Create a new product, process, or idea.
Judge: Form an opinion or conclusion about something.
Plan: Devise a method for doing or achieving something.
Produce: Make or manufacture something from components or raw materials.
Propose: Put forward an idea or plan for consideration.
Recommend: Suggest something as worthy of being adopted or done.
Revise: Reconsider and alter something in light of further evidence.
Synthesize: Combine different elements to form a coherent whole.
Validate: Demonstrate or support the truth or value of something.
"""

#### Define response structures
###############################################################
JSON_RESPONSE_SCHEMA = """{
        "score": 0 or 1,
        "rationale": "Your 2-line explanation here",
        "feedback": "Your 2-line feedback here"
      }"""

JSON_RESPONSE_SCHEMA_ALIGNMENT = """{
        "score": 0 or 1,
        "rationale": "Your 2-line explanation here",
        "ek_aligned": "the ek code that is aligned to the text"
        "lo_aligned": "the lo code that is aligned to the text"
        "skill_aligned": "the skill code that is aligned to the text"
    }"""

JSON_RESPONSE_SCHEMA_DIF_QTYPE = """{
        "score": 0 or 1,
        "rationale": "Your 2-line explanation here",
        "difficulty": "0, 1, 2, or 3",
        "questiontype": "Question type determined"
        }"""

# %%
###############################################################
###############################################################
############ Define Subject Specific Multishot ################
###############################################################
###############################################################

# Variables defined in this section:
# goodqs: historyGoodQs, scienceGoodQs
# badqs: socbadqs, scibadqs


# Define good questions for multishot
###############################################################
socgoodqs ="""
Question 1:
The measure of the average number of children who are born to women of childbearing age in the population is called the
actual birth rate
crude birth rate
total fertility rate
(Correct)
adjusted birth rate
net reproduction ratio

Question 2:
Which of the following characteristics is currently shared by Switzerland, Canada, and New Zealand?
Low population-growth rates
(Correct)
Primate urban systems
High infant-mortality rates
Membership in the European Union (EU)
More than ten percent of the population involved in sheep farming

Question 3:
Even though total fertility rates have been declining in some less-developed countries, the total population has continued to grow.  This is primarily because a high percentage  of the population is
female
male
over the age of 15
under the age of 15
(Correct)
receiving adequate medical care

Question 4:
Since the 1970s changes in the social roles, lifestyles, and employment patterns of women in Europe, Canada, and the United States have affected the overall population through which of the following?
Increased total fertility rates
Decreased total fertility rates
(Correct)
Increased death rates
Decreased death rates
Increased infant mortality rates

Question 5:
Which of the following compares the impact of increased global communications technology to the impact of state-controlled media?
Both global communication technology and state-controlled media act as centripetal forces that present a common message, which is utilized by the government to bind citizens together.
Neither global communications technology nor state-controlled media have any impact on the viability of a state when it comes to centripetal or centrifugal forces.
Global communications technology is utilized as a centripetal force to present a common message, whereas state-controlled media may bring in new ideas that act as centrifugal forces.
Both global communications technology and state-controlled media act as centrifugal forces because they give citizens access to concepts or ideas that may inspire dissent.
Global communications technology may bring in new ideas that act as centrifugal forces, whereas state-controlled media is utilized as a centripetal force to present a common message.

Question 6: Difficulty: 1
Before 1492, many American Indian cultures were strongly influenced by the
spread of corn cultivation
(Correct)
ravages of smallpox epidemics
regular contacts with Africa
invention of the spoked wheel
domestication of horses


Question 7: Difficulty: 1
1. The method of mass production that developed during the nineteenth century was a process that
relied on the use of power-driven machinery
(Correct)
utilized wireless communications to improve efficiency
gave workers greater autonomy, less supervision, and the chance to be creative
relied on guilds to train artisans
promoted more cooperation between labor unions and factory owners


Question 8: Difficulty 3
 “The petition of a great number of blacks detained in a state of slavery in the bowels of a free and Christian country humbly showeth that . . . they have in common with all other men a natural and inalienable right to that freedom which the Great Parent of the Universe has bestowed equally on all mankind, and which they have never forfeited by any compact or agreement whatever. . . .
Petition to the Massachusetts House of Representatives, January 1777
Arguments such as that in the excerpt contributed most directly to which of the following in the nineteenth century?
The extension of equal civil rights to African Americans in northern states
A growing sectional divide about slavery and its expansion
(Correct)
The migration of African Americans from the rural South to the urban North
The abolition of slavery in the southern states


Question 9. Difficulty 2
Which of the following contributed most significantly to a surge in western settlement during the 1860s and 1870s?
Dry seasons turned fertile land to semidesert and made real estate inexpensive.
A strong military eliminated attacks by Native Americans.
The expansion of railroads made the Great Plains more accessible.
(Correct)
The novels of romantics like Hamlin Garland glorified western life.
Government funding for irrigation projects made farms more profitable.


Question 10: Difficulty 2
Which of the following statements about woman suffrage is true?
The six states of New England were the first to have complete women suffrage.
Women suffrage was introduced in the South during Radical Reconstruction.
No state granted woman suffrage before 1900.
The only states with complete woman suffrage before 1900 were west of the Mississippi.
(Correct)
California and Oregon were the first states to have complete women suffrage.

"""
scienceGoodQs ="""
Question 6:
Difficulty: 2
Humans produce sweat as a cooling mechanism to maintain a stable internal temperature. Which of the following best explains how the properties of water contribute to this physiological process?
The high heat of vaporization of water allows the body to remove excess heat through a phase change of water from liquid to gas.
(Correct)
Explanation:
The high heat of vaporization of water is the key property that explains how sweating cools the body. When sweat evaporates from the skin, it requires a significant amount of heat energy to change from liquid to gas. This energy is taken from the body, thus cooling it down.
The high specific heat capacity of water allows the body to absorb a large amount of excess heat energy.
Explanation:
While it is true that water has a high specific heat capacity, which means it can absorb a lot of heat before increasing in temperature, this property is not directly responsible for the cooling mechanism of sweating. Sweating cools the body primarily through the process of evaporation, not through the absorption of heat.
The high surface tension of water contributes to the physical process by which water leaves the body.
Explanation:
The high surface tension of water is related to the cohesive forces between water molecules, but it does not play a significant role in the cooling mechanism of sweating. The cooling effect is primarily due to the evaporation of sweat, not the surface tension.
The high melting temperature of water allows the body to remove excess heat through a phase change of water from solid to liquid.
Explanation:
The high melting temperature of water refers to the temperature at which ice melts to become liquid water. This property is not relevant to the process of sweating, as sweating involves the evaporation of liquid water, not the melting of ice.

Question 7:
Difficulty: 1
Which of the following is responsible for the cohesive property of water?
Covalent bonds between the hydrogen atoms of two adjacent water molecules
Explanation:
This answer is incorrect because covalent bonds do not form between the hydrogen atoms of two adjacent water molecules. Covalent bonds are the strong bonds that hold the hydrogen and oxygen atoms together within a single water molecule.
Hydrogen bonds between water molecules and other types of molecules
Explanation:
This answer is incorrect because the cohesive property of water specifically refers to the attraction between water molecules themselves, not between water molecules and other types of molecules. Hydrogen bonds between water molecules and other types of molecules contribute to adhesion, not cohesion.
Hydrogen bonds between the oxygen atoms of two adjacent water molecules
Explanation:
This answer is incorrect because hydrogen bonds do not form between the oxygen atoms of two adjacent water molecules. Instead, hydrogen bonds form between the hydrogen atom of one water molecule and the oxygen atom of another water molecule.
Hydrogen bonds between the oxygen atom of one water molecule and a hydrogen atom of another water molecule
(Correct)
Explanation:
This answer is correct. The cohesive property of water is due to hydrogen bonds that form between the oxygen atom of one water molecule and the hydrogen atom of another water molecule. These hydrogen bonds create a network of interconnected water molecules, which gives water its cohesive nature.
Covalent bonds between the oxygen atom of one water molecule and a hydrogen atom of another water molecule
Explanation:
This answer is incorrect because covalent bonds do not form between the oxygen atom of one water molecule and a hydrogen atom of another water molecule. Covalent bonds are the strong bonds within a single water molecule, not between different water molecules.

Question 9:
Difficulty: 3
Antibiotics can be used to kill the specific pathogenic bacterium, Mycobacterium tuberculosis, that causes tuberculosis. The appearance of antibiotic-resistant strains has made it more difficult to cure M. tuberculosis infections. These antibiotic-resistant bacteria survive and pass on the genes to their offspring, making the resistant phenotype more common in the population.
DNA analysis indicates that the genes for antibiotic resistance are not normally present in bacterial chromosomal DNA
Which of the following statements best explains how the genes for antibiotic resistance can be transmitted between bacteria without the exchange of bacterial chromosomal DNA?
The antibiotic-resistant bacteria release a hormone that signals neighboring bacteria to become resistant.
The genes for antibiotic resistance are located on a plasmid that can be passed to neighboring bacteria.
(Correct)
The antibiotic-resistant bacteria are the result of bacteria that specifically modify their own chromosomal DNA to neutralize the antibiotics.
The antibiotic alters the bacterial genome of each bacterium, which results in an antibiotic-resistant population.

Question 10:
Difficulty: 2
Two types of cholesterol transport proteins, low-density lipoproteins (LDL) and high-density lipoproteins (HDL), bind to cholesterol and carry it through the bloodstream. Familial hypercholesterolemia (FH) is characterized by high cholesterol levels in the blood, which can lead to cardiovascular disease.
FH is associated with a loss-of-function mutation of a gene that encodes LDL receptors in liver cells. Individuals who are heterozygous produce lower-than-normal amounts of the LDL receptors, and individuals who are homozygous for the mutant allele have no LDL receptor function.
Individuals with FH can be treated with drugs that result in increased production of LDL receptors in liver cells. Which of the following best explains the observation that the drugs can effectively control blood cholesterol levels in individuals who are heterozygous but are not effective in individuals homozygous for the mutant allele?
The drugs repair the mutant allele by copying the wild-type allele.
The drugs prevent cholesterol from entering the liver cells in individuals who are heterozygous but not in individuals who are homozygous for the mutant allele.
Cholesterol molecules primarily bind to HDL receptors in individuals with FH.
There must be at least one copy of the wild-type LDL receptor allele to produce functional LDL receptors.
(Correct)

Question 1:
Difficulty: 2
The apple maggot fly, Rhagoletis pomonella, is native to North America and originally fed on fruit of the wild hawthorn. Since the mid-1800s, a population of flies has emerged that instead feed on domesticated apples. Apple maggot flies typically mate on or near the fruit of their host plants. Many varieties of apples ripen three to four weeks before the hawthorn fruits do.
The different fruit preferences of the two fly populations will most likely have which of the following effects?
The flies that eat hawthorn fruit will increase in number, while the flies that eat apples will decrease in number because of the use of insecticides on apple trees.
The single fly species will evolve into two distinct species because of the lack of gene flow between the two populations.
(Correct)
The ability to survive on a diet of two different fruits will help the flies learn to eat many more types of fruit.
The flies that eat hawthorn fruit will lay some of their eggs on the earlier-ripening apples to minimize competition among the larvae.
"""

# Define bad questions for multishot
###############################################################
socbadqs="""
HISTORY BAD Qs {
          "question": "In what way did Neo-Confucianism emerge as a response to Buddhism during the Song Dynasty? \nA It completely rejected all Buddhist teachings and practices.\nB It integrated some Buddhist concepts while reinforcing Confucian values, creating a syncretic philosophy. \nC It promoted atheism as a new belief system among scholars. \nD It led to widespread persecution of Buddhist monks and temples throughout China.",
          "pass": false,
          "reason": "Absolute statements using words like all, every, never, completely, entirely, complete, are not plausible distractors."
        }
{
          "question": "Which of the following factors contributed most significantly to the agricultural productivity of Song China?\nA The adoption of crop rotation methods from Europe \n B The introduction of Champa rice from Vietnam (correct) \nC The use of chemical fertilizers developed in India \nD The implementation of large-scale irrigation systems from Mesopotamia",
          "pass": false,
          "reason": "The distractor option C too obviously false because it is a technology from a time period more than 600 years apart from the song dynasty"
        }
 {
          "question": "The role of women in Song Dynasty society was characterized by:        \nA) Complete equality with men in all aspects of public and private life. \nB) Increased economic opportunities alongside persistent social restrictions. \nC) Exclusion from all forms of education and literary pursuits. \nD) Mandatory participation in the civil service examination system.",
          "pass": false,
          "reason": "Distractors contain absolute statements such as all, complete, completely, never"
        }
        {
          "question": "The impact of Neo-Confucianism on Song Dynasty society can be best described as:\nA) A return to pure, unadulterated early Confucian thought without any new interpretations. \nB) A complete rejection of Confucian principles in favor of Buddhist and Daoist philosophies.\nC) A reinterpretation of Confucian ideas that reinforced social hierarchy and moral cultivation. \nD) An emphasis on individual spiritual enlightenment at the expense of social responsibilities.",
          "pass": false,
          "reason": "Distractors are obvious due to words such as all, complete, completely, never"
        }
  {
          "question": "In what way did the Song Dynasty's approach to commerce differ from previous dynasties, and what was a significant economic consequence of this approach?\n\nA By imposing strict trade restrictions, it minimized foreign influence and reduced economic growth.\nB By promoting maritime trade and technological innovations, it led to the commercialization of the economy.(correct) \nC By focusing solely on land-based trade routes like the Silk Road, it neglected naval advancements.\nD By adopting a barter system over currency, it simplified transactions but limited economic complexity.\n",
          "pass": false,
          "reason": "Neither the correct response nor any of the distractors respond to both parts of the question. The question asks for the difference from previous dynasties as well as the economic consequence. meaning there is no correct repsonse available"
        }

{
          "question": "What primarily facilitated diverse economic exchanges between different Indigenous groups before European colonization?        \nA CORRECT: Established trade networks based on regional resource specializations\nB A universally accepted system of coinage used across tribes \nCContracts enforced through a centralized legal authority \nD Digital communication platforms facilitating long.distance barter deals\n",
          "pass": false,
          "reason": "Distractor not a believable lie because it is wildly out of time period suggesting digital networks between 1200 & 1400"
        }
        {
          "question": "How did environmental factors most likely affect political structures in native societies before European arrival?\nA Varied climates led to different subsistence strategies that influenced social hierarchy and governance. \nB Frequent volcanic eruptions prompted a unified pan.Native American political coalition.\nC Widespread desertification drove the creation of continent.wide democratic assemblies. \nD Seasonal monsoons standardized government forms across all native societies on the continent.\n",
          "pass": false,
          "reason": "Distractors not plausible because students would not believe these lies. They are too silly."
        }
 {
          "question": "How did the differing views on land use between Europeans and Native Americans reflect their broader worldviews during the early interactions in North America?\n\nA Both Europeans and Native Americans believed land should be respected and not exploited for economic gain.\nB Both Europeans and Native Americans believed land was meant to be owned individually and used for personal gain.\nC The Europeans viewed land as a commodity for ownership, while Native Americans saw it as a shared resource. \nD Both Europeans and Native Americans believed land should be owned privately and used for farming.\n",
          "pass": false,
          "reason": "Neither the correct response nor any of the distractors connect the concepts in the question. The question asks for an explanation of how views on land use reflect broader world views. All response options address only views on land use meaning there is no correct repsonse available"
        }
"""
scibadqs="""
Bio BADQs {
          "question": "If a substance has molar mass of 58 g/mol, how many grams of this substance would you need to have exactly 2 moles?\nA 58 grams (for 1 mole)\nB 116 grams\nC 29 grams (for .5 moles)\nD 116 grams (incorrect calculation)",
          "pass": false,
          "reason": "116 grams and 116 grams (incorrect calculation) are identical because 116 grams is the correct calculation. The addition of these words is meaningless"
        },
        {
          "question": "Which of the following statements correctly describes a vector quantity?\nA vector quantity has both magnitude and direction.\n(Correct)\nA vector quantity only has magnitude and does not have direction.\nA vector quantity only has magnitude and does not have direction.\nA vector quantity is defined solely by its magnitude.\n",
          "pass": false,
          "reason": "All 3 distractors have the same meaning with different wording"
        },
        {
          "question": "Question 3\nWhich of the following correctly represents a vector with a magnitude of 5 meters directed to the left?\nA vâƒ— = -5 m \nB vâƒ— = 5 m\nC vâƒ— = 5 m (to the right)\nD vâƒ— = 5 m (direction unspecified)",
          "pass": false,
          "reason": "Within the context of vector notation,  the negative sign inherently denotes movement to the left, a positive value would then indicate movement to the right. All three distractors then have the same meaning and 5m (direction not specified) does not make sense as a response"
        }
{
          "question": "What is the average atomic mass of chlorine based on the given isotopic masses and their relative abundances?\nA 35.438 amu\nB 34.968 amu\nC 36.000 amu\nD  37.500 amu\n",
          "pass": false,
          "reason": "The question suggests that the isotopic mass and relative abundance is offered, but it is not provided. The student could not calculate a value without this data."
        },
        {
          "question": "In a chemical reaction, if 0.5 moles of a reactant decompose to produce a product, how many molecules of the product are formed? (Use Avogadro's number, which is approximately $6.022 \\times 10^{23}$ molecules/mole) \na 3.01 x 10^23 molecules\nb 6.02 x 10^23 molecules\nc 4.01 x 10^23 molecules\nd 1.00 x 10^24 molecules\n",
          "pass": false,
          "reason": "The answer to this question is dependent on the stoichiometry of the deomposition"
        },
"""

# %%
###############################################################
###############################################################
############ Define Course Specific Filepaths #################
###############################################################
###############################################################

#Lesson Plan Variables Defined in this section
### soc:   LP_APAPUSGOV, LP_APHUMG, LP_APUSH, LP_APWORLD, LP_APEURO
### ssc:   LP_APMACRO, LP_APMICRO, LP_APPSYCH
### sci:   LP_APBIO, LP_APCHEM, LP_APENVS, LP_APPHY1, LP_APPHY2, LP_APPHYCEM, LP_APPHYCMEC
### eng:   LP_APLANG, LP_APLIT,
### mat:   LP_APCALCAB, LP_APCALCBC, LP_APPRECALC, LP_APSTAT
### csc:   LP_APCSCA, LP_APCSCP

# Lesson Plans -
### All LPs must use same variable  naming structure
### DRIs are then responsible for what is generated by placing the only the content they want generated into the input sheet.

###############################################################

## Lesson Plan Variables Defined in this section
## All lesson plans to be pulled from sheet.name(Gen_Input)
## This allows DRIs to determine which content they want generated without transition to the engineers,
## other option is to adjust code to handle unit, topic, and article level selection
#SOC:
LP_APAPUSGOV =""
# APHUMG https://docs.google.com/spreadsheets/d/1_mOhHhBxxxuSolLnMTGfaYTrN5FZMzSEVZj-_TVMRr8/edit?gid=2005197127#gid=2005197127
LP_APHUMG ="1_mOhHhBxxxuSolLnMTGfaYTrN5FZMzSEVZj-_TVMRr8"
LP_APUSH ="12GxsAWmKOWPawLOql8WEcwic1tw8NVYjHjbhBf8bdvQ"
LP_APWORLD ="16RXbw2Prs_lXVcN2Z5EOq5agscQTkBD-0ZpUIt06m0k"
LP_APEURO =""
#SSC:
LP_APMACRO =""
LP_APMICRO ="1MEE2ogX9wnpWkhoRk0LNbnC-jwKW6a9BE-8XZroiJ3k"
LP_APPSYCH =""
#SCI:
LP_APBIO ="1PekdsSKyLvCR5Z6nO1p3-yw6l4QIefNqNr3oPQPS25A"
LP_APCHEM ="1KdTor8f0FaODaJakHK5170VnNYi8QxirhBmd9gHvvGc"
LP_APENVS =""
LP_APPHY1 ="1YRO55kAFVbulMZj3dxpEtJNPdJ_zQX-l5JDxSOGFbag"
LP_APPHY2 =""
LP_APPHYCEM =""
LP_APPHYCMEC =""
#ENG
LP_APLANG =""
LP_APLIT =""
#MAT
LP_APCALCAB  =""
LP_APCALCBC =""
LP_APPRECALC =""
LP_APSTAT =""
#CSC
LP_APCSCA =""
LP_APCSCP =""

# %%
###############################################################
###############################################################
########## Set variables by subject or Course #################
###############################################################
###############################################################

############################################
# Define the mapping for courses to subjects
############################################
course_to_subject = {
    "soc": ["APCGOV","APAPUSGOV", "APHUMG", "APUSH", "APWORLD", "APEURO"],
    "ssc": ["APMACRO", "APMICRO", "APPSYCH"],
    "sci": ["APBIO", "APCHEM", "APENVS", "APPHY1", "APPHY2", "APPHYCEM", "APPHYCMEC"],
    "eng": ["APLANG", "APLIT"],
    "mat": ["APCALCAB", "APCALCBC", "APPRECALC", "APSTAT"],
    "csc": ["APCSCA", "APCSCP"]
}
subject = None
for subj, courses in course_to_subject.items():
    if course in courses:
        subject = subj
        break

# Handle unknown courses
if subject is None:
    subject = "unknown"

# Print the result
print(f"The course '{course}' belongs to the subject: {subject}")


############################################
# Define the mapping variables to subjects
############################################

# Define the goodqs & badqs based on the subject
#################################################
goodqs = globals()[f"{subject}goodqs"]
badqs = globals()[f"{subject}badqs"]


# Define the gen prompts based on the subject
#################################################
# genmcq_Q_prompt, genmcq_correct_prompt, genmcq_distractor_prompt, genmcq_explanation_prompt

genmcq_Q_prompt = globals()[f"{subject}genmcq_Q_prompt"]
genmcq_correct_prompt = globals()[f"{subject}genmcq_correct_prompt"]
genmcq_distractor_prompt = globals()[f"{subject}genmcq_distractor_prompt"]
genmcq_explanation_prompt = globals()[f"{subject}genmcq_explanation_prompt"]


if withStimulus == 1:
    genrefmcq_Q_prompt = globals()[f"{subject}genrefmcq_Q_prompt"]
    genreffrq_Q_prompt = globals()[f"{subject}genreffrq_Q_prompt"]


# Define the qc prompts based on the subject
#################################################
qcmcq_prompt01Clarity = globals()[f"{subject}qcmcq_prompt01Clarity"]
qcmcq_prompt02Format = globals()[f"{subject}qcmcq_prompt02Format"]
qcmcq_prompt03Content = globals()[f"{subject}qcmcq_prompt03Content"]
qcmcq_prompt04Curriculum = globals()[f"{subject}qcmcq_prompt04Curriculum"]
qcmcq_prompt05Difficulty = globals()[f"{subject}qcmcq_prompt05Difficulty"]
qcmcq_prompt06Correct = globals()[f"{subject}qcmcq_prompt06Correct"]
qcmcq_prompt07Distractor    = globals()[f"{subject}qcmcq_prompt07Distractor   "]
qcmcq_prompt08Absolutes   = globals()[f"{subject}qcmcq_prompt08Absolutes  "]
qcmcq_prompt09Responses  = globals()[f"{subject}qcmcq_prompt09Responses "]
qcmcq_prompt10Explanations  = globals()[f"{subject}qcmcq_prompt10Explanations "]



# Define the fix prompts based on the subject
#################################################
#socfixmcq_prompt01Clarity socfixmcq_prompt02TaskVerb  socfixmcq_prompt03Correct socfixmcq_prompt04Absolutes socfixmcq_prompt05Distractors socfixmcq_propmt06Responses socfixmcq_prompt07Difficulty socfixmcq_prompt08Explanation socfixmcq_prompt09Question
fixmcq_prompt01Clarity = globals()[f"{subject}fixmcq_prompt01Clarity"]
fixmcq_prompt02TaskVerb = globals()[f"{subject}fixmcq_prompt02TaskVerb"]
fixmcq_prompt03Correct = globals()[f"{subject}fixmcq_prompt03Correct"]
fixmcq_prompt04Absolutes = globals()[f"{subject}fixmcq_prompt04Absolutes"]
fixmcq_prompt05Distractors = globals()[f"{subject}fixmcq_prompt05Distractors"]
fixmcq_propmt06Responses    = globals()[f"{subject}fixmcq_propmt06Responses   "]
fixmcq_prompt07Difficulty   = globals()[f"{subject}fixmcq_prompt07Difficulty  "]
fixmcq_prompt08Explanation  = globals()[f"{subject}fixmcq_prompt08Explanation "]
fixmcq_prompt09Question  = globals()[f"{subject}fixmcq_prompt09Question "]

# %%
###############################################################
###############################################################
# Now tell me what to do
###############################################################
###############################################################


###############################################################
# Generate 01.00.00
# Current QC for template: https://colab.research.google.com/drive/16p4Zx7UL5-GKMvplTtFddV6eDQCDo9Ld?usp=sharing
###############################################################
if genArticle == 1:
    subprocess.run([
        "python",
        r"C:\\Users\\sarah\\Documents\\Trilogy\\GenCycle\\00_01_00_GenArticle.py",
        prompt1,
        prompt2
    ])
if genMCQ == 1:
    subprocess.run([
        "python",
        r"C:\\Users\\sarah\\Documents\\Trilogy\\GenCycle\\00_02_00_GenMCQ.py",
        genmcq_Q_prompt,
        genmcq_correct_prompt,
        genmcq_distractor_prompt,
        genmcq_explanation_prompt
    ])
if genFRQ == 1:
    subprocess.run([
        "python",
        r"C:\\Users\\sarah\\Documents\\Trilogy\\GenCycle\\00_03_00_GenFRQ.py",
        prompt1,
        prompt2
    ])

# %%
###############################################################
# Now tell me what to do: QC 02.00.00
# Current QC for template: https://colab.research.google.com/drive/1X88zRYUVpYhul2kUcZEbTOhwziTU6YTF?usp=sharing
###############################################################
if qcArticle == 1:
    subprocess.run([
        "python",
        r"C:\\Users\\sarah\\Documents\\Trilogy\\GenCycle\\00_01_00_GenArticle.py",
        prompt1,
        prompt2
    ])
if qcMCQ == 1:
    subprocess.run([
        "python",
        r"C:\\Users\\sarah\\Documents\\Trilogy\\GenCycle\\00_01_00_GenArticle.py",
        qcmcq_prompt01Clarity,
        qcmcq_prompt02Format,
        qcmcq_prompt03Content,
        qcmcq_prompt04Curriculum,
        qcmcq_prompt05Difficulty,
        qcmcq_prompt06Correct,
        qcmcq_prompt07Distractor,
        qcmcq_prompt08Absolutes,
        qcmcq_prompt09Responses,
        qcmcq_prompt10Explanations
    ])
if qcFRQ == 1:
    subprocess.run([
        "python",
        r"C:\\Users\\sarah\\Documents\\Trilogy\\GenCycle\\00_01_00_GenArticle.py",
        prompt1,
        prompt2
    ])

# %%
###############################################################
# Now tell me what to do: Fix 03.00.00
# Revises content based on QC feedback
###############################################################
if fixArticle == 1:
    subprocess.run([
        "python",
        r"C:\\Users\\sarah\\Documents\\Trilogy\\GenCycle\\00_01_00_GenArticle.py",
        prompt1,
        prompt2
    ])
if fixMCQ == 1:
    subprocess.run([
        "python",
        r"C:\\Users\\sarah\\Documents\\Trilogy\\GenCycle\\00_01_00_GenArticle.py",
        fixmcq_prompt01Clarity,
        fixmcq_prompt02TaskVerb,
        fixmcq_prompt03Correct,
        fixmcq_prompt04Absolutes,
        fixmcq_prompt05Distractors,
        fixmcq_propmt06Responses,
        fixmcq_prompt07Difficulty,
        fixmcq_prompt08Explanation,
        fixmcq_prompt09Question
    ])
if fixFRQ == 1:
    subprocess.run([
        "python",
        r"C:\\Users\\sarah\\Documents\\Trilogy\\GenCycle\\00_01_00_GenArticle.py",
        prompt1,
        prompt2
    ])

# %%
###############################################################
# Now tell me what to do: QC Fixed 04.00.00
# Repeat initial QC but with different set of vars
# Current QC for template: https://colab.research.google.com/drive/1X88zRYUVpYhul2kUcZEbTOhwziTU6YTF?usp=sharing
###############################################################
if qcFixArticle== 1:
    subprocess.run([
        "python",
        r"C:\\Users\\sarah\\Documents\\Trilogy\\GenCycle\\00_01_00_GenArticle.py",
        prompt1,
        prompt2
    ])
if qcFixMCQ == 1:
    subprocess.run([
        "python",
        r"C:\\Users\\sarah\\Documents\\Trilogy\\GenCycle\\00_01_00_GenArticle.py",
        qcmcq_prompt01Clarity,
        qcmcq_prompt02Format,
        qcmcq_prompt03Content,
        qcmcq_prompt04Curriculum,
        qcmcq_prompt05Difficulty,
        qcmcq_prompt06Correct,
        qcmcq_prompt07Distractor,
        qcmcq_prompt08Absolutes,
        qcmcq_prompt09Responses,
        qcmcq_prompt10Explanations
    ])
if qcFFRQ == 1:
    subprocess.run([
        "python",
        r"C:\\Users\\sarah\\Documents\\Trilogy\\GenCycle\\00_01_00_GenArticle.py",
        prompt1,
        prompt2
    ])
